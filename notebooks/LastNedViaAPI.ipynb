# %% [markdown]
# # Analyse av trafikksikkerhetsdata
# Denne notebooken er laget for p hente ned NVDB data om ulykker

# %%
import nvdbapiv3 as nvdb
import json

# %%
q = nvdb.nvdbFagdata(570) 
# (Status=Operativ OR Status=Midlertidig ute av drift) AND Trafikantgruppe=Sykkel
#q.filter({"egenskap": "(5201=7081 OR 5201=12987) AND 9293=12993"})

from tqdm.notebook import tqdm_notebook
ut_fil_navn = '../data/API_data.json'

with open(ut_fil_navn, 'w') as ut_fil:
    ut_fil.write('[')
    o = q.nesteForekomst()
    i = 0 
    ut_fil.write('\n' + json.dumps(o) )
    #for teller in range(5):
    while o: # Dette funker ikke er noe som ikke stemmer her rapporter None -> vi går for CSV nedlasting
        o = q.nesteForekomst()
        if o:
            ut_fil.write( ',' + '\n' + json.dumps(o) )
            i += 1
            if i%10000 == 0:
                print(i)
    print(i)
    ut_fil.write('\n]')
print("Ferdig")
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 290428
# Ferdig

# %%
import json
# load data using Python JSON module
with open('../data/API_data_50Test.json','r') as f:
    data = json.loads(f.read())# Flatten data
    
df_flat = pd.json_normalize(data, max_level=None)

df_flat.head()

#import pandas as pd

#df = pd.read_json('../data/API_data.json')
# Out:
#          id                                               href  \
# 0  78639815  https://nvdbapiles-v3.atlas.vegvesen.no/vegobj...
# 1  78639818  https://nvdbapiles-v3.atlas.vegvesen.no/vegobj...
# 2  78639823  https://nvdbapiles-v3.atlas.vegvesen.no/vegobj...
# 3  78639829  https://nvdbapiles-v3.atlas.vegvesen.no/vegobj...
# 4  78639836  https://nvdbapiles-v3.atlas.vegvesen.no/vegobj...
#
#                                           egenskaper  \
# 0  [{'id': 100570, 'navn': 'PunktTilknytning', 'e...
# 1  [{'id': 100570, 'navn': 'PunktTilknytning', 'e...
# 2  [{'id': 100570, 'navn': 'PunktTilknytning', 'e...
# 3  [{'id': 100570, 'navn': 'PunktTilknytning', 'e...
# 4  [{'id': 100570, 'navn': 'PunktTilknytning', 'e...
#
#                                         vegsegmenter  metadata.type.id  \
# 0  [{'veglenkesekvensid': 384110, 'relativPosisjo...               570
# 1  [{'veglenkesekvensid': 384014, 'relativPosisjo...               570
# ...

# %%
jalla =pd.json_normalize(df_flat['egenskaper'])
jalla
# Out:
#                                                   0   \
# 0  {'id': 100570, 'navn': 'PunktTilknytning', 'eg...
# 1  {'id': 100570, 'navn': 'PunktTilknytning', 'eg...
# 2  {'id': 100570, 'navn': 'PunktTilknytning', 'eg...
# 3  {'id': 100570, 'navn': 'PunktTilknytning', 'eg...
# 4  {'id': 100570, 'navn': 'PunktTilknytning', 'eg...
# 5  {'id': 100570, 'navn': 'PunktTilknytning', 'eg...
#
#                                                   1   \
# 0  {'id': 220693, 'navn': 'Assosierte Ulykkesinvo...
# 1  {'id': 220693, 'navn': 'Assosierte Ulykkesinvo...
# 2  {'id': 220693, 'navn': 'Assosierte Ulykkesinvo...
# 3  {'id': 220693, 'navn': 'Assosierte Ulykkesinvo...
# 4  {'id': 220693, 'navn': 'Assosierte Ulykkesinvo...
# 5  {'id': 220693, 'navn': 'Assosierte Ulykkesinvo...
#
#                                                   2   \
# 0  {'id': 5123, 'navn': 'Geometri, punkt', 'egens...
# 1  {'id': 5123, 'navn': 'Geometri, punkt', 'egens...
# ...
